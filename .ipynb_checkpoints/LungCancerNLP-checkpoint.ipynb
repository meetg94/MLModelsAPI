# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('cancer patient data sets.csv')

# %%
data.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %%
data.shape
# Out:
# (1000, 26)

# %%
data.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
data.dtypes
# Out:
# index                        int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %%
data.describe()
# Out:
#              index          Age       Gender  Air Pollution  Alcohol use  \
# count  1000.000000  1000.000000  1000.000000      1000.0000  1000.000000
# mean    499.500000    37.174000     1.402000         3.8400     4.563000
# std     288.819436    12.005493     0.490547         2.0304     2.620477
# min       0.000000    14.000000     1.000000         1.0000     1.000000
# 25%     249.750000    27.750000     1.000000         2.0000     2.000000
# 50%     499.500000    36.000000     1.000000         3.0000     5.000000
# 75%     749.250000    45.000000     2.000000         6.0000     7.000000
# max     999.000000    73.000000     2.000000         8.0000     8.000000
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count   1000.000000           1000.000000   1000.000000           1000.000000
# mean       5.165000              4.840000      4.580000              4.380000
# ...

# %%
print(data['Level'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %%
grouped_data = data.groupby(['Gender', 'Level'])
gender_level_counts = grouped_data.size()
print(gender_level_counts)
# Out:
# Gender  Level
# 1       High      252
#         Low       149
#         Medium    197
# 2       High      113
#         Low       154
#         Medium    135
# dtype: int64

# %%
data.columns = data.columns.str.lower().str.replace(' ', '_')

# %%
data.columns
# Out:
# Index(['index', 'patient_id', 'age', 'gender', 'air_pollution', 'alcohol_use',
#        'dust_allergy', 'occupational_hazards', 'genetic_risk',
#        'chronic_lung_disease', 'balanced_diet', 'obesity', 'smoking',
#        'passive_smoker', 'chest_pain', 'coughing_of_blood', 'fatigue',
#        'weight_loss', 'shortness_of_breath', 'wheezing',
#        'swallowing_difficulty', 'clubbing_of_finger_nails', 'frequent_cold',
#        'dry_cough', 'snoring', 'level'],
#       dtype='object')

# %%
data['level'].value_counts()
# Out:
# High      365
# Medium    332
# Low       303
# Name: level, dtype: int64

# %%
data.corr()
# Out:
#                              index       age    gender  air_pollution  \
# index                     1.000000  0.002674 -0.025739       0.053307
# age                       0.002674  1.000000 -0.202086       0.099494
# gender                   -0.025739 -0.202086  1.000000      -0.246912
# air_pollution             0.053307  0.099494 -0.246912       1.000000
# alcohol_use               0.041374  0.151742 -0.227636       0.747293
# dust_allergy              0.037960  0.035202 -0.204312       0.637503
# occupational_hazards      0.032355  0.062177 -0.192343       0.608924
# genetic_risk              0.030725  0.073151 -0.222727       0.705276
# chronic_lung_disease      0.025177  0.128952 -0.205061       0.626701
# balanced_diet             0.030743  0.004863 -0.099741       0.524873
# obesity                   0.050584  0.034337 -0.123813       0.601468
# smoking                   0.018407  0.075333 -0.206924       0.481902
# ...

# %%
corr_matrix = data.corr()

# %%
#Plotting correlation matrix as a heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#Bivariate Analysis between age and level
input_variable = 'age'
target_variable = 'level'

plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x=target_variable, y=input_variable)
plt.xlabel(target_variable)
plt.ylabel(target_variable)
plt.title(f"Bivariate Analysis: {input_variable} vs {target_variable}")
plt.show()

# %%
#Bivariate Analysis between age and level
input_variables = ["smoking", "air_pollution", "obesity"]
target_variable = "level"

fig, axes = plt.subplots(nrows=1, ncols=len(input_variables), figsize=(15, 6))

# Iterate through each input variable and create a visualization
for i, input_variable in enumerate(input_variables):
    ax = axes[i]
    sns.boxplot(data=data, x=target_variable, y=input_variable, ax=ax)
    ax.set_xlabel(target_variable)
    ax.set_ylabel(input_variable)
    ax.set_title(f"Bivariate Analysis: {input_variable} vs {target_variable}")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['age'], bins=10, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram - Age')
plt.show()

# %%
# Example: Scatter plot of 'age' vs. 'target'
plt.figure(figsize=(8, 6))
plt.scatter(data['age'], data['level'])
plt.xlabel('Age')
plt.ylabel('Level')
plt.title('Scatter Plot - Age vs. Level')
plt.show()

# %%
#Encoding level to numerical values
data['level'] = data['level'].str.lower()
data['level_encoded'] = data['level'].map({'low': 0, 'medium': 1, 'high': 2})

# %%
data.columns
# Out:
# Index(['index', 'patient_id', 'age', 'gender', 'air_pollution', 'alcohol_use',
#        'dust_allergy', 'occupational_hazards', 'genetic_risk',
#        'chronic_lung_disease', 'balanced_diet', 'obesity', 'smoking',
#        'passive_smoker', 'chest_pain', 'coughing_of_blood', 'fatigue',
#        'weight_loss', 'shortness_of_breath', 'wheezing',
#        'swallowing_difficulty', 'clubbing_of_finger_nails', 'frequent_cold',
#        'dry_cough', 'snoring', 'level', 'level_encoded'],
#       dtype='object')

# %%
missing_values = data.isna().sum()

# %%
print(missing_values)
# Out:
# age                         0
# gender                      0
# air_pollution               0
# alcohol_use                 0
# dust_allergy                0
# occupational_hazards        0
# genetic_risk                0
# chronic_lung_disease        0
# balanced_diet               0
# obesity                     0
# smoking                     0
# passive_smoker              0
# chest_pain                  0
# coughing_of_blood           0
# fatigue                     0
# weight_loss                 0
# shortness_of_breath         0
# wheezing                    0
# swallowing_difficulty       0
# clubbing_of_finger_nails    0
# frequent_cold               0
# dry_cough                   0
# snoring                     0
# level_encoded               0
# dtype: int64

# %%
gender_counts = data['gender'].value_counts()
print(gender_counts)
# Out:
# 1    598
# 2    402
# Name: gender, dtype: int64

# %%
print(data['level'].unique())
# Out:
# ['low' 'medium' 'high']

# %%
data.columns
# Out:
# Index(['index', 'patient_id', 'age', 'gender', 'air_pollution', 'alcohol_use',
#        'dust_allergy', 'occupational_hazards', 'genetic_risk',
#        'chronic_lung_disease', 'balanced_diet', 'obesity', 'smoking',
#        'passive_smoker', 'chest_pain', 'coughing_of_blood', 'fatigue',
#        'weight_loss', 'shortness_of_breath', 'wheezing',
#        'swallowing_difficulty', 'clubbing_of_finger_nails', 'frequent_cold',
#        'dry_cough', 'snoring', 'level', 'level_encoded'],
#       dtype='object')

# %%
data = data.drop(['patient_id', 'index', 'level'], axis=1)

# %%
data.columns
# Out:
# Index(['age', 'gender', 'air_pollution', 'alcohol_use', 'dust_allergy',
#        'occupational_hazards', 'genetic_risk', 'chronic_lung_disease',
#        'balanced_diet', 'obesity', 'smoking', 'passive_smoker', 'chest_pain',
#        'coughing_of_blood', 'fatigue', 'weight_loss', 'shortness_of_breath',
#        'wheezing', 'swallowing_difficulty', 'clubbing_of_finger_nails',
#        'frequent_cold', 'dry_cough', 'snoring', 'level_encoded'],
#       dtype='object')

# %%
# Categorize the data into genetic, gender, and environmental factors
genetic_columns = ['age', 'genetic_risk', 'chronic_lung_disease']
gender_columns = ['gender']
environmental_columns = ['air_pollution', 'alcohol_use', 'dust_allergy',
                         'occupational_hazards', 'chronic_lung_disease',
                         'balanced_diet', 'obesity', 'smoking',
                         'passive_smoker', 'chest_pain', 'coughing_of_blood',
                         'fatigue', 'weight_loss', 'shortness_of_breath',
                         'wheezing', 'swallowing_difficulty',
                         'clubbing_of_finger_nails', 'frequent_cold',
                         'dry_cough', 'snoring']

# Subset the data based on the categories
genetic_data = data[genetic_columns]
gender_data = data[gender_columns]
environmental_data = data[environmental_columns]

# %%
environmental_data.columns
# Out:
# Index(['air_pollution', 'alcohol_use', 'dust_allergy', 'occupational_hazards',
#        'chronic_lung_disease', 'balanced_diet', 'obesity', 'smoking',
#        'passive_smoker', 'chest_pain', 'coughing_of_blood', 'fatigue',
#        'weight_loss', 'shortness_of_breath', 'wheezing',
#        'swallowing_difficulty', 'clubbing_of_finger_nails', 'frequent_cold',
#        'dry_cough', 'snoring'],
#       dtype='object')

# %%
len(environmental_data.columns)
# Out:
# 21

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# First we need to make sure 'age' is treated as a numeric column. If it's not, convert it.
data['age'] = pd.to_numeric(data['age'], errors='coerce')

# Compute the average age for each level
average_age_by_level = data.groupby('level_encoded')['age'].mean()

# Reset the index to convert the index into a column
average_age_by_level = average_age_by_level.reset_index()

# Plot the data
plt.figure(figsize=(10, 6))
sns.barplot(x='level_encoded', y='age', data=average_age_by_level)
plt.title('Average age by level')
plt.xlabel('level_encoded')
plt.ylabel('Average age')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# Convert all categorical variables to numeric format
for column in data.columns:
    data[column] = pd.to_numeric(data[column], errors='coerce')

# Define the features and target
features = ['air_pollution', 'alcohol_use', 'dust_allergy', 'occupational_hazards',
            'chronic_lung_disease', 'balanced_diet', 'obesity', 'smoking',
            'passive_smoker', 'chest_pain', 'coughing_of_blood', 'fatigue',
            'weight_loss', 'shortness_of_breath', 'wheezing',
            'swallowing_difficulty', 'clubbing_of_finger_nails', 'frequent_cold',
            'dry_cough', 'snoring']

target = 'level_encoded'

# Initialize the model
model = RandomForestClassifier(n_estimators=100, random_state=0)

# Fit the model
model.fit(data[features], data[target])

# Get the feature importances
importances = model.feature_importances_

# Convert the importances into a pandas DataFrame
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
})

# Sort the DataFrame by the importance
importance_df_RFC = importance_df.sort_values(by='Importance', ascending=False)

# %%
import xgboost 
from xgboost import XGBClassifier

# Initialize the model
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# Fit the model
model.fit(data[features], data[target])

# Get feature importances
importances = model.feature_importances_

# Create a DataFrame of feature importances
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
})

# Sort DataFrame by the importance column
importance_df_xGBC = importance_df.sort_values(by='Importance', ascending=False)
# Out:
# /Users/meetg/opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Initialize the model
model = GradientBoostingClassifier(random_state=0)

# Fit the model
model.fit(data[features], data[target])

# Get feature importances
importances = model.feature_importances_

# Create a DataFrame of feature importances
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
})

# Sort DataFrame by the importance column
importance_df_GBC = importance_df.sort_values(by='Importance', ascending=False)

# %%
# First, let's merge all three dataframes on 'Feature'
merged_df = pd.merge(importance_df_RFC, importance_df_xGBC, on='Feature', suffixes=('_RFC', '_xGBC'))
merged_df = pd.merge(merged_df, importance_df_GBC, on='Feature')
merged_df.rename(columns={'Importance': 'Importance_GBC'}, inplace=True)

# Now, let's compute the mean importance across all models
merged_df['Mean_Importance'] = merged_df[['Importance_RFC', 'Importance_xGBC', 'Importance_GBC']].mean(axis=1)

# Sort the DataFrame by the mean importance
merged_df.sort_values(by='Mean_Importance', ascending=False, inplace=True)

# %%
# Get the names of the top features
top_features = merged_df.head(15)['Feature'].tolist()

print(top_features)
# Out:
# ['coughing_of_blood', 'alcohol_use', 'fatigue', 'wheezing', 'smoking', 'passive_smoker', 'obesity', 'dust_allergy', 'frequent_cold', 'clubbing_of_finger_nails', 'shortness_of_breath', 'air_pollution', 'snoring', 'balanced_diet', 'occupational_hazards']

# %%
selected_columns = top_features + gender_columns + genetic_columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
import pickle

# Choose your features and target
X = data[selected_columns]  # Put your selected feature names here
y = data['level_encoded']

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and fit the model
model = GradientBoostingClassifier(random_state=42)
model.fit(X_train, y_train)

# Save the trained model to a file
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Make predictions
y_pred = model.predict(X_test)

# Measure accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 100.00%

# %%
import pickle

# Save the trained model to a file
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)
